# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-GTHUB/Diabetes_Prediction/blob/main/Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['.config', 'diabetes_prediction_dataset.csv', 'sample_data']

# %%
df = pd.read_csv('/content/diabetes_prediction_dataset.csv')

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df = df.drop(columns = 'smoking_history' )

# %%
df
# Out:
#        gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      Female  80.0             0              1  25.19          6.6
# 1      Female  54.0             0              0  27.32          6.6
# 2        Male  28.0             0              0  27.32          5.7
# 3      Female  36.0             0              0  23.45          5.0
# 4        Male  76.0             1              1  20.14          4.8
# ...       ...   ...           ...            ...    ...          ...
# 99995  Female  80.0             0              0  27.32          6.2
# 99996  Female   2.0             0              0  17.37          6.5
# 99997    Male  66.0             0              0  27.83          5.7
# 99998  Female  24.0             0              0  35.42          4.0
# 99999  Female  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes
# 0                      140         0
# 1                       80         0
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
df['gender'].replace(['Male', 'Female', 'Other'], ['0', '1', '2'],inplace=True)

# %%
df
# Out:
#       gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0          1  80.0             0              1  25.19          6.6
# 1          1  54.0             0              0  27.32          6.6
# 2          0  28.0             0              0  27.32          5.7
# 3          1  36.0             0              0  23.45          5.0
# 4          0  76.0             1              1  20.14          4.8
# ...      ...   ...           ...            ...    ...          ...
# 99995      1  80.0             0              0  27.32          6.2
# 99996      1   2.0             0              0  17.37          6.5
# 99997      0  66.0             0              0  27.83          5.7
# 99998      1  24.0             0              0  35.42          4.0
# 99999      1  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes
# 0                      140         0
# 1                       80         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   bmi                  100000 non-null  float64
#  5   HbA1c_level          100000 non-null  float64
#  6   blood_glucose_level  100000 non-null  int64
#  7   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 6.1+ MB

# %%
X = df.iloc[:,:-1]
print(X)
# Out:
#       gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0          1  80.0             0              1  25.19          6.6
# 1          1  54.0             0              0  27.32          6.6
# 2          0  28.0             0              0  27.32          5.7
# 3          1  36.0             0              0  23.45          5.0
# 4          0  76.0             1              1  20.14          4.8
# ...      ...   ...           ...            ...    ...          ...
# 99995      1  80.0             0              0  27.32          6.2
# 99996      1   2.0             0              0  17.37          6.5
# 99997      0  66.0             0              0  27.83          5.7
# 99998      1  24.0             0              0  35.42          4.0
# 99999      1  57.0             0              0  22.43          6.6
#
#        blood_glucose_level
# 0                      140
# 1                       80
# 2                      158
# 3                      155
# ...

# %%
Y = df.iloc[:,-1]

# %%
print(Y)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, random_state=101)

# %%
X_train
# Out:
#       gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 38823      0  43.0             0              0  23.17          4.0
# 78870      1  47.0             0              0  28.53          6.6
# 28393      1  73.0             0              1  38.32          6.5
# 64349      1  67.0             0              0  38.53          6.5
# 23027      0   1.4             0              0  14.88          3.5
# ...      ...   ...           ...            ...    ...          ...
# 5695       0  38.0             0              0  19.26          6.2
# 73542      0  31.0             0              0  36.38          5.8
# 83281      0  80.0             1              0  26.75          6.6
# 83467      0  52.0             0              0  30.91          8.8
# 45919      1  49.0             0              0  22.53          5.7
#
#        blood_glucose_level
# 38823                  140
# 78870                  200
# 28393                  140
# 64349                  140
# ...

# %%
Y_train
# Out:
# 38823    0
# 78870    0
# 28393    1
# 64349    0
# 23027    0
#         ..
# 5695     1
# 73542    0
# 83281    0
# 83467    1
# 45919    0
# Name: diabetes, Length: 80000, dtype: int64

# %% [markdown]
# #Importing GaussianNB Model

# %%
from sklearn.naive_bayes import GaussianNB

# %%
g = GaussianNB()

# %%
g.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
y_pred = g.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac = accuracy_score(Y_test, y_pred)

# %%
ac
# Out:
# 0.90475

# %% [markdown]
# # By Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
sv = SVC()

# %%
sv.fit(X_train, Y_train)
# Out:
# SVC()

# %%
y_pred = sv.predict(X_test)

# %%
ac = accuracy_score(Y_test, y_pred)

# %%
ac
# Out:
# 0.94845
